# %% [markdown]
# ## Template de chaîne de traitement

# %% [markdown]
# En nous servant de nos connaissances et des briques développées par l’ensemble de la classe, nous allons proposer un rapport un template de chaine de traitement sous la forme d’un notebook (qui pourrait être repris dans la phase 2).

# %% [markdown]
# ### Step1: Data cleaning

# %% [markdown]
#     Drops any columns that have more than 50% missing values
#     Removes leading and trailing spaces from column names
#     Converts all string columns to lowercase
#     Removes any duplicate rows
#     Converts any date columns to datetime format
#     Removes any non-numeric characters from numeric columns
#     Fills missing values with the mean or median of the column
#     Removes outliers in numeric columns using the IQR method
#     Standardizes the numeric columns using the StandardScaler

# %% [markdown]
# ### Step 2: data transform

# %% [markdown]
# Data scaling

# %% [markdown]
# Filter by cols

# %% [markdown]
# Non numercal Features encodage

# %% [markdown]
# ### Step 3: Feature selection

# %% [markdown]
# VarianceThreshold

# %% [markdown]
# ### Step 4: Data analysis and exporation

# %% [markdown]
# Univariate analysis

# %% [markdown]
# Multivariate analysis

# %% [markdown]
# Relationship between variables visualise data

# %% [markdown]
# Implementing the umap to reduce variables

# %% [markdown]
# Interactive visualization to explore the data

# %% [markdown]
# Train and optimise clustering algorithms

# %% [markdown]
# Test a heriarchical classification or clustering method

# %% [markdown]
# ### Step 5: Results interpretation

# %% [markdown]
# Interpretation of cluster results

# %% [markdown]
# Intepretation of result from the step 4

# %% [markdown]
# ###

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=5c55c619-12aa-4496-bd5e-22d280e8df64' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
