# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r"C:\Users\Fnac\Desktop\Trello ML\Trello_git/teaching_ml_2023/dataset_clean.csv", encoding='utf-8')

# %%
df
# Out:
#                       code      created_datetime  \
# 0            0000000000017  2018-06-15T10:38:00Z
# 1            0000000000031  2018-10-13T21:06:14Z
# 2       000000000003327986  2019-11-19T15:02:16Z
# 3            0000000000100  2015-10-11T14:09:21Z
# 4     00000000001111111111  2019-06-08T18:56:13Z
# ...                    ...                   ...
# 9995         0011150039840  2017-03-09T16:12:37Z
# 9996         0011150039857  2017-03-09T09:59:57Z
# 9997         0011150039864  2017-03-09T09:54:29Z
# 9998         0011150039871  2017-03-09T09:59:57Z
# 9999         0011150039925  2017-03-09T09:54:31Z
#
#                       product_name         brands  \
# 0                 Vitória crackers            NaN
# 1                            Cacao            NaN
# 2        Filetes de pollo empanado            NaN
# 3      moutarde au moût de raisin   courte paille
# 4                          Sfiudwx           Watt
# ...                            ...            ...
# 9995          Great Northern Beans       Roundy's
# 9996             Drink Mix Packets       Roundy's
# 9997              Green Split Peas       Roundy's
# 9998             Drink Mix Packets       Roundy's
# 9999                       Lentils       Roundy's
#
#                                              categories   countries_en  \
# 0                                                   NaN         France
# 1                                                   NaN         France
# 2                                                   NaN          Spain
# 3               Epicerie, Condiments, Sauces, Moutardes         France
# 4                                                   Xsf         France
# ...                                                 ...            ...
# 9995                                                NaN  United States
# 9996                                                NaN  United States
# 9997                                    Vegetable mixes  United States
# 9998                                                NaN  United States
# 9999  Plant-based foods and beverages, Plant-based f...  United States
#
#                                        ingredients_text  additives_n  \
# 0                                                   NaN          NaN
# 1                                                   NaN          NaN
# 2                                                   NaN          NaN
# 3     eau graines de téguments de moutarde vinaigre ...          0.0
# 4                                                   NaN          NaN
# ...                                                 ...          ...
# 9995                               Great northern beans          0.0
# 9996  Citric acid, maltodextrin, instant tea, corn s...          9.0
# 9997                                  Green split peas.          0.0
# 9998  Citric acid, maltodextrin, instant tea, aspart...          7.0
# 9999                                           Lentils.          0.0
#
#              pnns_groups_2                                             states  \
# 0                  unknown  en:to-be-completed, en:nutrition-facts-complet...
# 1                  unknown  en:to-be-completed, en:nutrition-facts-to-be-c...
# 2                  unknown  en:to-be-completed, en:nutrition-facts-to-be-c...
# 3     Dressings and sauces  en:to-be-completed, en:nutrition-facts-complet...
# 4                  unknown  en:to-be-completed, en:nutrition-facts-to-be-c...
# ...                    ...                                                ...
# 9995               unknown  en:to-be-completed, en:nutrition-facts-complet...
# 9996               unknown  en:to-be-completed, en:nutrition-facts-complet...
# 9997               unknown  en:to-be-completed, en:nutrition-facts-complet...
# 9998               unknown  en:to-be-completed, en:nutrition-facts-complet...
# 9999               Legumes  en:to-be-completed, en:nutrition-facts-complet...
#
#       energy-kcal_100g  energy_100g  fat_100g  saturated-fat_100g  \
# 0                375.0       1569.0       7.0                3.08
# 1                  NaN          NaN       NaN                 NaN
# 2                  NaN          NaN       NaN                 NaN
# 3                  NaN        936.0       8.2                2.20
# 4                  NaN          NaN       NaN                 NaN
# ...                ...          ...       ...                 ...
# 9995             194.0        812.0       0.0                0.00
# 9996             500.0       2092.0       0.0                 NaN
# 9997             244.0       1021.0       0.0                0.00
# 9998             500.0       2092.0       0.0                 NaN
# 9999             219.0        916.0       0.0                0.00
#
#       carbohydrates_100g  sugars_100g  fiber_100g  proteins_100g  salt_100g  \
# 0                  70.10        15.00         NaN           7.80    1.40000
# 1                    NaN          NaN         NaN            NaN        NaN
# 2                    NaN          NaN         NaN            NaN        NaN
# 3                  29.00        22.00         0.0           5.10    4.60000
# 4                    NaN          NaN         NaN            NaN        NaN
# ...                  ...          ...         ...            ...        ...
# 9995               61.11         2.78        36.1          22.22    0.14224
# 9996                0.00         0.00         NaN           0.00    0.00000
# 9997               60.00         2.22        24.4          24.44    0.14000
# 9998                0.00         0.00         NaN           0.00    0.00000
# 9999               59.38         0.00        28.1          25.00    0.04064
#
#       sodium_100g
# 0        0.560000
# 1             NaN
# 2             NaN
# 3        1.840000
# 4             NaN
# ...           ...
# 9995     0.056896
# 9996     0.000000
# 9997     0.056000
# 9998     0.000000
# 9999     0.016256
#
# [10000 rows x 20 columns]

# %%
def gestion_valeurs_aberrantes(df, colonnes=None, seuil=3, action="delete"):
    
    """
        ------------------------------------------------------------------------------------------------------------------------------------
        Objectif : 
        ------------
        Cette fonction prend en entrée un dataframe, une liste de colonnes, un seuil et une action à effectuer en cas de valeurs aberrantes.
        Elle renvoie un dataframe modifié selon l'action choisie.
        --------------
        Paramètres
        --------------
        df: dataframe contenant les données
        colonnes: liste des noms des colonnes à traiter (par défaut, toutes les colonnes sont traitées)
        seuil: seuil utilisé pour déterminer les valeurs aberrantes (par défaut, seuil = 3)
        action: action à effectuer en cas de valeurs aberrantes ("delete" pour supprimer, "mean" pour remplacer par la moyenne)
        ---------------
        En sortie: dataframe modifié selon l'action choisie
        -------------------------------------------------------------------------------------------------------------------------------------
        
    """
    # Si aucune colonne n'est spécifiée, on traite toutes les colonnes
    if colonnes is None:
        colonnes = df.columns
    
    # Calcule de la moyenne et de l'écart-type pour chaque colonne spécifiée
    moyennes = np.mean(df[colonnes], axis=0)
    ecarts_types = np.std(df[colonnes], axis=0)
    
    # Détermination des valeurs aberrantes pour chaque colonne spécifiée
    valeurs_aberrantes = (df[colonnes] < moyennes - seuil * ecarts_types) | (df[colonnes] > moyennes + seuil * ecarts_types)
    
    # Suppression ou remplacement des lignes contenant des valeurs aberrantes
    if action == "delete":
        df_modifie = df[~np.any(valeurs_aberrantes, axis=1)]
    elif action == "mean":
        df_modifie = df.copy()
        for c in colonnes:
            df_modifie[c] = np.where(valeurs_aberrantes[c], moyennes[c], df_modifie[c])
    else:
        raise ValueError("L'action choisie n'est pas valide. Veuillez choisir 'delete' ou 'mean'.")
    
    return df_modifie

# Sélection des variables numériques dont nous souhaitons gérer les valeurs abbérantes
colonnes_float = df.select_dtypes(include=['float']).columns
df_sans_aberrantes = gestion_valeurs_aberrantes(df,colonnes_float,seuil=3, action="delete")
df_sans_aberrantes
# Out:
#                       code      created_datetime  \
# 0            0000000000017  2018-06-15T10:38:00Z
# 1            0000000000031  2018-10-13T21:06:14Z
# 2       000000000003327986  2019-11-19T15:02:16Z
# 3            0000000000100  2015-10-11T14:09:21Z
# 4     00000000001111111111  2019-06-08T18:56:13Z
# ...                    ...                   ...
# 9989         0011150039758  2017-03-09T17:15:35Z
# 9991         0011150039772  2017-03-09T09:59:52Z
# 9993         0011150039819  2017-03-09T09:59:56Z
# 9996         0011150039857  2017-03-09T09:59:57Z
# 9998         0011150039871  2017-03-09T09:59:57Z
#
#                       product_name         brands  \
# 0                 Vitória crackers            NaN
# 1                            Cacao            NaN
# 2        Filetes de pollo empanado            NaN
# 3      moutarde au moût de raisin   courte paille
# 4                          Sfiudwx           Watt
# ...                            ...            ...
# 9989         Liquid Water Enhancer       Roundy's
# 9991             Drink Mix Packets       Roundy's
# 9993                     Drink Mix       Roundy's
# 9996             Drink Mix Packets       Roundy's
# 9998             Drink Mix Packets       Roundy's
#
#                                    categories   countries_en  \
# 0                                         NaN         France
# 1                                         NaN         France
# 2                                         NaN          Spain
# 3     Epicerie, Condiments, Sauces, Moutardes         France
# 4                                         Xsf         France
# ...                                       ...            ...
# 9989                                      NaN  United States
# 9991                                      NaN  United States
# 9993                                      NaN  United States
# 9996                                      NaN  United States
# 9998                                      NaN  United States
#
#                                        ingredients_text  additives_n  \
# 0                                                   NaN          NaN
# 1                                                   NaN          NaN
# 2                                                   NaN          NaN
# 3     eau graines de téguments de moutarde vinaigre ...          0.0
# 4                                                   NaN          NaN
# ...                                                 ...          ...
# 9989  Water, propylene glycol, malic acid, citric ac...          7.0
# 9991  Citric acid, natural and artificial flavor, po...          6.0
# 9993  Citric acid, potassium and sodium citrate, nat...          8.0
# 9996  Citric acid, maltodextrin, instant tea, corn s...          9.0
# 9998  Citric acid, maltodextrin, instant tea, aspart...          7.0
#
#              pnns_groups_2                                             states  \
# 0                  unknown  en:to-be-completed, en:nutrition-facts-complet...
# 1                  unknown  en:to-be-completed, en:nutrition-facts-to-be-c...
# 2                  unknown  en:to-be-completed, en:nutrition-facts-to-be-c...
# 3     Dressings and sauces  en:to-be-completed, en:nutrition-facts-complet...
# 4                  unknown  en:to-be-completed, en:nutrition-facts-to-be-c...
# ...                    ...                                                ...
# 9989               unknown  en:to-be-completed, en:nutrition-facts-complet...
# 9991               unknown  en:to-be-completed, en:nutrition-facts-complet...
# 9993               unknown  en:to-be-completed, en:nutrition-facts-complet...
# 9996               unknown  en:to-be-completed, en:nutrition-facts-complet...
# 9998               unknown  en:to-be-completed, en:nutrition-facts-complet...
#
#       energy-kcal_100g  energy_100g  fat_100g  saturated-fat_100g  \
# 0                375.0       1569.0       7.0                3.08
# 1                  NaN          NaN       NaN                 NaN
# 2                  NaN          NaN       NaN                 NaN
# 3                  NaN        936.0       8.2                2.20
# 4                  NaN          NaN       NaN                 NaN
# ...                ...          ...       ...                 ...
# 9989               0.0          0.0       0.0                 NaN
# 9991             417.0       1745.0       0.0                 NaN
# 9993             250.0       1046.0       0.0                 NaN
# 9996             500.0       2092.0       0.0                 NaN
# 9998             500.0       2092.0       0.0                 NaN
#
#       carbohydrates_100g  sugars_100g  fiber_100g  proteins_100g  salt_100g  \
# 0                   70.1         15.0         NaN            7.8      1.400
# 1                    NaN          NaN         NaN            NaN        NaN
# 2                    NaN          NaN         NaN            NaN        NaN
# 3                   29.0         22.0         0.0            5.1      4.600
# 4                    NaN          NaN         NaN            NaN        NaN
# ...                  ...          ...         ...            ...        ...
# 9989                 0.0          0.0         NaN            0.0      0.000
# 9991                 0.0          0.0         NaN            0.0      0.000
# 9993                 0.0          0.0         NaN            0.0      4.445
# 9996                 0.0          0.0         NaN            0.0      0.000
# 9998                 0.0          0.0         NaN            0.0      0.000
#
#       sodium_100g
# 0           0.560
# 1             NaN
# 2             NaN
# 3           1.840
# 4             NaN
# ...           ...
# 9989        0.000
# 9991        0.000
# 9993        1.778
# 9996        0.000
# 9998        0.000
#
# [9193 rows x 20 columns]
