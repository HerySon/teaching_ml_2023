# %%
import pandas as pd
import numpy as np
df = pd.read_csv(r"C:\Users\Fnac\Desktop\Trello ML\Trello_git/teaching_ml_2023/tests\dataset_clean.csv", encoding='utf-8')

# %%
df
# Out:
#                       code      created_datetime  \
# 0            0000000000017  2018-06-15T10:38:00Z
# 1            0000000000031  2018-10-13T21:06:14Z
# 2       000000000003327986  2019-11-19T15:02:16Z
# 3            0000000000100  2015-10-11T14:09:21Z
# 4     00000000001111111111  2019-06-08T18:56:13Z
# ...                    ...                   ...
# 9995         0011150039840  2017-03-09T16:12:37Z
# 9996         0011150039857  2017-03-09T09:59:57Z
# 9997         0011150039864  2017-03-09T09:54:29Z
# 9998         0011150039871  2017-03-09T09:59:57Z
# 9999         0011150039925  2017-03-09T09:54:31Z
#
#                       product_name         brands  \
# 0                 Vitória crackers            NaN
# 1                            Cacao            NaN
# 2        Filetes de pollo empanado            NaN
# 3      moutarde au moût de raisin   courte paille
# 4                          Sfiudwx           Watt
# ...                            ...            ...
# 9995          Great Northern Beans       Roundy's
# 9996             Drink Mix Packets       Roundy's
# 9997              Green Split Peas       Roundy's
# 9998             Drink Mix Packets       Roundy's
# 9999                       Lentils       Roundy's
#
#                                              categories   countries_en  \
# 0                                                   NaN         France
# 1                                                   NaN         France
# 2                                                   NaN          Spain
# 3               Epicerie, Condiments, Sauces, Moutardes         France
# 4                                                   Xsf         France
# ...                                                 ...            ...
# 9995                                                NaN  United States
# 9996                                                NaN  United States
# 9997                                    Vegetable mixes  United States
# 9998                                                NaN  United States
# 9999  Plant-based foods and beverages, Plant-based f...  United States
#
#                                        ingredients_text  additives_n  \
# 0                                                   NaN          NaN
# 1                                                   NaN          NaN
# 2                                                   NaN          NaN
# 3     eau graines de téguments de moutarde vinaigre ...          0.0
# 4                                                   NaN          NaN
# ...                                                 ...          ...
# 9995                               Great northern beans          0.0
# 9996  Citric acid, maltodextrin, instant tea, corn s...          9.0
# 9997                                  Green split peas.          0.0
# 9998  Citric acid, maltodextrin, instant tea, aspart...          7.0
# 9999                                           Lentils.          0.0
#
#      nutriscore_grade         pnns_groups_2  ... cholesterol_100g  \
# 0                 NaN               unknown  ...              NaN
# 1                 NaN               unknown  ...              NaN
# 2                 NaN               unknown  ...              NaN
# 3                   d  Dressings and sauces  ...              NaN
# 4                 NaN               unknown  ...              NaN
# ...               ...                   ...  ...              ...
# 9995              NaN               unknown  ...              0.0
# 9996              NaN               unknown  ...              NaN
# 9997                a               unknown  ...              0.0
# 9998              NaN               unknown  ...              NaN
# 9999                a               Legumes  ...              0.0
#
#       carbohydrates_100g  sugars_100g  fiber_100g  proteins_100g  salt_100g  \
# 0                  70.10        15.00         NaN           7.80    1.40000
# 1                    NaN          NaN         NaN            NaN        NaN
# 2                    NaN          NaN         NaN            NaN        NaN
# 3                  29.00        22.00         0.0           5.10    4.60000
# 4                    NaN          NaN         NaN            NaN        NaN
# ...                  ...          ...         ...            ...        ...
# 9995               61.11         2.78        36.1          22.22    0.14224
# 9996                0.00         0.00         NaN           0.00    0.00000
# 9997               60.00         2.22        24.4          24.44    0.14000
# 9998                0.00         0.00         NaN           0.00    0.00000
# 9999               59.38         0.00        28.1          25.00    0.04064
#
#       sodium_100g  calcium_100g  iron_100g  nutrition-score-fr_100g
# 0        0.560000           NaN        NaN                      NaN
# 1             NaN           NaN        NaN                      NaN
# 2             NaN           NaN        NaN                      NaN
# 3        1.840000           NaN        NaN                     18.0
# 4             NaN           NaN        NaN                      NaN
# ...           ...           ...        ...                      ...
# 9995     0.056896         0.167    0.00400                      NaN
# 9996     0.000000           NaN        NaN                      NaN
# 9997     0.056000         0.000    0.00600                      NaN
# 9998     0.000000           NaN        NaN                      NaN
# 9999     0.016256         0.000    0.00844                      NaN
#
# [10000 rows x 26 columns]

# %%
def scale_data(df, method,hyperparams=None):
  
    """
        ------------------------------------------------------------------------------
        Goal : 
            - Applies data scaling according to the chosen method
            (MinMax or Standard or norm or robust)
        ------------------------------------------------------------------------------
        Parameters:
        - df : Dataset to be analyzed
        - method: method used to scale the data ('standard' for StandardScaler, 'norm' 
                 for Normalizer,'robust' for RobustScaler, 'minmax' for MinMaxScaler).
                 N.B: Default = 'standard'
        -----------------------------------------------------------------------------
        Return :
        -  Returns a daframe.
        -----------------------------------------------------------------------------
    """
      
    #Useful libraries  
    from sklearn.preprocessing import StandardScaler, MinMaxScaler, Normalizer, RobustScaler
    
    #Selecting the numeric variables we want to scale
    colonnes_float = df.select_dtypes(include=['number']).columns
    
    #Handle missing values by replacing them with the median
    df[colonnes_float] = df[colonnes_float].fillna(df[colonnes_float].median())

    # Choice of scaler 
    if method == "minmax":
        scaler = MinMaxScaler(**hyperparams) if hyperparams else MinMaxScaler()
    elif method == "Standard":
        scaler = StandardScaler() if hyperparams else StandardScaler()
    elif method == "norm":
        scaler = Normalizer() if hyperparams else Normalizer()
    elif method == "Robust":
        scaler = RobustScaler() if hyperparams else RobustScaler()
    else:
        raise ValueError(f"Unknown scaling method: {method}")
        return None

    #Scale selected numeric variables
    df[colonnes_float] = scaler.fit_transform(df[colonnes_float])

    # Return scaled dataset
    return df

# Apply MinMax scaling with custom hyperparameters
hyperparams = {"feature_range": (0, 1)}
df_scaled = scale_data(df, method="minmax", hyperparams=hyperparams)
df_scaled
# Out:
#                       code      created_datetime  \
# 0            0000000000017  2018-06-15T10:38:00Z
# 1            0000000000031  2018-10-13T21:06:14Z
# 2       000000000003327986  2019-11-19T15:02:16Z
# 3            0000000000100  2015-10-11T14:09:21Z
# 4     00000000001111111111  2019-06-08T18:56:13Z
# ...                    ...                   ...
# 9995         0011150039840  2017-03-09T16:12:37Z
# 9996         0011150039857  2017-03-09T09:59:57Z
# 9997         0011150039864  2017-03-09T09:54:29Z
# 9998         0011150039871  2017-03-09T09:59:57Z
# 9999         0011150039925  2017-03-09T09:54:31Z
#
#                       product_name         brands  \
# 0                 Vitória crackers            NaN
# 1                            Cacao            NaN
# 2        Filetes de pollo empanado            NaN
# 3      moutarde au moût de raisin   courte paille
# 4                          Sfiudwx           Watt
# ...                            ...            ...
# 9995          Great Northern Beans       Roundy's
# 9996             Drink Mix Packets       Roundy's
# 9997              Green Split Peas       Roundy's
# 9998             Drink Mix Packets       Roundy's
# 9999                       Lentils       Roundy's
#
#                                              categories   countries_en  \
# 0                                                   NaN         France
# 1                                                   NaN         France
# 2                                                   NaN          Spain
# 3               Epicerie, Condiments, Sauces, Moutardes         France
# 4                                                   Xsf         France
# ...                                                 ...            ...
# 9995                                                NaN  United States
# 9996                                                NaN  United States
# 9997                                    Vegetable mixes  United States
# 9998                                                NaN  United States
# 9999  Plant-based foods and beverages, Plant-based f...  United States
#
#                                        ingredients_text  additives_n  \
# 0                                                   NaN     0.060606
# 1                                                   NaN     0.060606
# 2                                                   NaN     0.060606
# 3     eau graines de téguments de moutarde vinaigre ...     0.000000
# 4                                                   NaN     0.060606
# ...                                                 ...          ...
# 9995                               Great northern beans     0.000000
# 9996  Citric acid, maltodextrin, instant tea, corn s...     0.272727
# 9997                                  Green split peas.     0.000000
# 9998  Citric acid, maltodextrin, instant tea, aspart...     0.212121
# 9999                                           Lentils.     0.000000
#
#      nutriscore_grade         pnns_groups_2  ... cholesterol_100g  \
# 0                 NaN               unknown  ...              0.0
# 1                 NaN               unknown  ...              0.0
# 2                 NaN               unknown  ...              0.0
# 3                   d  Dressings and sauces  ...              0.0
# 4                 NaN               unknown  ...              0.0
# ...               ...                   ...  ...              ...
# 9995              NaN               unknown  ...              0.0
# 9996              NaN               unknown  ...              0.0
# 9997                a               unknown  ...              0.0
# 9998              NaN               unknown  ...              0.0
# 9999                a               Legumes  ...              0.0
#
#       carbohydrates_100g  sugars_100g  fiber_100g  proteins_100g  salt_100g  \
# 0               0.175250       0.1500    0.018182        0.01950   0.000683
# 1               0.058825       0.0650    0.018182        0.01200   0.000293
# 2               0.058825       0.0650    0.018182        0.01200   0.000293
# 3               0.072500       0.2200    0.000000        0.01275   0.002244
# 4               0.058825       0.0650    0.018182        0.01200   0.000293
# ...                  ...          ...         ...            ...        ...
# 9995            0.152775       0.0278    0.410227        0.05555   0.000069
# 9996            0.000000       0.0000    0.018182        0.00000   0.000000
# 9997            0.150000       0.0222    0.277273        0.06110   0.000068
# 9998            0.000000       0.0000    0.018182        0.00000   0.000000
# 9999            0.148450       0.0000    0.319318        0.06250   0.000020
#
#       sodium_100g  calcium_100g  iron_100g  nutrition-score-fr_100g
# 0        0.000682      0.007050   0.000072                 0.388889
# 1        0.000292      0.007050   0.000072                 0.388889
# 2        0.000292      0.007050   0.000072                 0.388889
# 3        0.002241      0.007050   0.000072                 0.500000
# 4        0.000292      0.007050   0.000072                 0.388889
# ...           ...           ...        ...                      ...
# 9995     0.000069      0.025049   0.000301                 0.388889
# 9996     0.000000      0.007050   0.000072                 0.388889
# 9997     0.000068      0.000000   0.000452                 0.388889
# 9998     0.000000      0.007050   0.000072                 0.388889
# 9999     0.000020      0.000000   0.000636                 0.388889
#
# [10000 rows x 26 columns]
